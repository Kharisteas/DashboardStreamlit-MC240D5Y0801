# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Kharisteas Josan Sedi]
# - **Email:** [zerojosan777@gmail.com]
# - **ID Dicoding:** [kharisjos]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa faktor yang paling memengaruhi total penjualan di platform e-commerce ini?
# - Bagaimana tren penjualan berdasarkan kategori produk sepanjang waktu?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#baca datasetnya di path yang sesuai
data = pd.read_csv('/content/sample_data/order_reviews_dataset.csv')

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
print(data.head())
print(data.info())
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %%
#menghapus baris dengan review_comment_message yang kosong
data = data.dropna(subset=['review_comment_message'])

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
#descriptive statistics
print(data['review_score'].describe())
print(data['review_score'].value_counts())
# Out:
# count    40977.000000
# mean         3.669864
# std          1.615418
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: review_score, dtype: float64
# review_score
# 5    20554
# 1     8745
# 4     5976
# 3     3557
# 2     2145
# Name: count, dtype: int64

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# Bagaimana distribusi skor ulasan dari pelanggan, dan apakah terdapat tren positif atau negatif dalam ulasan selama periode waktu tertentu?

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Apa kata-kata yang paling sering muncul dalam ulasan positif dibandingkan dengan ulasan negatif?

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
#visualisasi untuk pertanyaan 1
plt.figure(figsize=(10,6))
sns.countplot(x='review_score', data=data)
plt.title('Distribusi Skor Ulasan')
plt.xlabel('Skor Ulasan')
plt.ylabel('Jumlah Ulasan')
plt.show()

#menghitung ulasan positif dan negatif
data['sentiment'] = data ['review_score'].apply(lambda x: 'positif' if x>= 4 else 'negatif')

#word cloud untuk pertanyaan 2
positive_reviews = ' '.join(data[data['sentiment'] == 'positif']['review_comment_message'])
negative_reviews = ' '.join(data[data['sentiment'] == 'negatif']['review_comment_message'])

wordcloud_positive = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews)
wordcloud_negative = WordCloud(width=800, height=400, background_color='white').generate(negative_reviews)

plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Ulasan Positif')

plt.subplot(1,2,2)
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Ulasan Negatif')

plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 :
#   Dari visualisasi distribusi skor ulasan, kita bisa melihat jumlah ulasan yang paling banyak berada pada skor 4 dan 5, yang menunjukkan bahwa sebagian besar pelanggan memberikan ulasan positif. Namun, ada juga ulasan negatif, terutama pada skor 1 dan 2, yang perlu diperhatikan untuk perbaikan kedepannya.
#
#
# ---
#
#
# - Conclution pertanyaan 2 : Dari analisis kata-kata yang sering muncul di word cloud, kita dapat melihat bahwa kata-kata positif seperti "bagus", "puas", dan "cepat" lebih sering muncul di ulasan positif. Sebaliknya, dalam ulasan negatif, kata-kata seperti "jelek", "lama", dan "tidak puas" mendominasi, menunjukkan area-area yang perlu diperbaiki
